# %% [markdown]
# ## Detector de boras - SOBEL
# O operador de Sobel realiza uma operação para realçar contornos em imagens. Esse tipo de filtro é não linear e realça linhas verticais e horizontais mais escuras que o fundo, sem realçar pontos isolados.
#
# Além dessas características, o detector de sobel possibilita realçar as arestas independente da direção: a filtragem pode ser realizada tanto vertical quanto horizontalmente.
#
# As regiões destacadas por esse procedimento resultam em bordas mais "grossas" comparadas as outras técnicas.

# %% [markdown]
# Imports

# %%
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Lendo imagens

# %%
path = r'C:\Users\shuel\Documents\Workspace\computer-vision\computer-vision-meganha\003-edge-filter\images'
img = cv2.imread(path + '\predio.jpg')

# %%
print(img)
# Out:
# [[[188 180 173]
#   [188 180 173]
#   [189 181 174]
#   ...
#   [252 242 232]
#   [251 241 231]
#   [251 241 231]]
#
#  [[188 180 173]
#   [189 181 174]
#   [189 181 174]
#   ...
#   [252 242 232]
#   [251 241 231]
#   [251 241 231]]
#
#  [[189 181 174]
#   [189 181 174]
#   [190 182 175]
#   ...
#   [252 242 232]
#   [251 241 231]
#   [251 241 231]]
#
#  ...
#
#  [[ 13  42  63]
#   [ 15  29  51]
#   [  5   7   1]
#   ...
#   [ 14  21  40]
#   [ 12  14  24]
#   [ 10   4   5]]
#
#  [[ 32  92 152]
#   [ 31  68 112]
#   [  3   4   2]
#   ...
#   [  5  29  59]
#   [  7  26  41]
#   [  3   4   8]]
#
#  [[ 10  81 155]
#   [  5  54 104]
#   [  2   0   0]
#   ...
#   [  0  26  60]
#   [  0  21  43]
#   [  5   6  16]]]

# %% [markdown]
# função Sobel(img, var_arm, h, v, máscara)
# Entrada:
#
#         1. Img = Imagem com a qual queremos trabalhar.
#         2. var_arm = Valor que representa o pixel
#         3. h = Realce horizontal
#         4. v = Realce vertical
#         5. máscara = dimensão de máscara que será aplicada
#
# Sáida:
#
#         1. Matriz referente a imagem com o realce do filtro Sobel

# %%
sobelx = cv2.Sobel(img, cv2.CV_8U, 0, 1, ksize=7)
sobely = cv2.Sobel(img, cv2.CV_8U, 1, 0, ksize=7)

# %%
fig = plt.figure(figsize=(20,50))

ax1 = fig.add_subplot(131)
plt.imshow(img)

ax2 = fig.add_subplot(132)
plt.imshow(sobelx)

ax3 = fig.add_subplot(133)
plt.imshow(sobely)

plt.show()
